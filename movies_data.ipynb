# %%
import pandas as pd

# %%
df = pd.read_csv('movie.csv')
df.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 3                       The Dark Knight Rises  2012.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0     Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0         Sam Mendes          0.0  Christoph Waltz    11000.0
# 3     164.0  Christopher Nolan      22000.0        Tom Hardy    27000.0
# 4       NaN        Doug Walker        131.0      Doug Walker      131.0
#
#              actor2  ...  actor3_fb        gross  \
# ...

# %%
# df.notna().sum()
df.isnull().sum()
# Out:
# title                0
# year               106
# color               19
# content_rating     300
# duration            15
# director_name      102
# director_fb        102
# actor1               7
# actor1_fb            7
# actor2              13
# actor2_fb           13
# actor3              23
# actor3_fb           23
# gross              862
# genres               0
# num_reviews         49
# num_voted_users      0
# plot_keywords      152
# language            12
# country              5
# budget             484
# imdb_score           0
# dtype: int64

# %%
df.shape
# Out:
# (4916, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            4916 non-null   object
#  1   year             4810 non-null   float64
#  2   color            4897 non-null   object
#  3   content_rating   4616 non-null   object
#  4   duration         4901 non-null   float64
#  5   director_name    4814 non-null   object
#  6   director_fb      4814 non-null   float64
#  7   actor1           4909 non-null   object
#  8   actor1_fb        4909 non-null   float64
#  9   actor2           4903 non-null   object
#  10  actor2_fb        4903 non-null   float64
#  11  actor3           4893 non-null   object
#  12  actor3_fb        4893 non-null   float64
#  13  gross            4054 non-null   float64
#  14  genres           4916 non-null   object
#  15  num_reviews      4867 non-null   float64
# ...

# %% [markdown]
# ### TASK 1 : Segregate movies with actors, imdb score more 6 less 8.1,

# %%
df1 =df[(df['imdb_score']>6) & (df['imdb_score']<8.1) ]

# %%
df1.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
# 5                                 John Carter  2012.0  Color          PG-13
#
#    duration   director_name  director_fb           actor1  actor1_fb  \
# 0     178.0   James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0  Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0      Sam Mendes          0.0  Christoph Waltz    11000.0
# 4       NaN     Doug Walker        131.0      Doug Walker      131.0
# 5     132.0  Andrew Stanton        475.0     Daryl Sabara      640.0
#
#              actor2  ...  actor3_fb        gross  \
# ...

# %%
df1 = df1[['title','actor1', 'actor2', 'imdb_score']]

# %%
df1.head()
# Out:
#                                         title           actor1  \
# 0                                      Avatar      CCH Pounder
# 1    Pirates of the Caribbean: At World's End      Johnny Depp
# 2                                     Spectre  Christoph Waltz
# 4  Star Wars: Episode VII - The Force Awakens      Doug Walker
# 5                                 John Carter     Daryl Sabara
#
#              actor2  imdb_score
# 0  Joel David Moore         7.9
# 1     Orlando Bloom         7.1
# 2      Rory Kinnear         6.8
# 4        Rob Walker         7.1
# 5   Samantha Morton         6.6

# %% [markdown]
# ### TASK 2 : Segregate movies initial ten rows with condition actor2_fb less than 300 more than 11000

# %%
df2= df[(df['actor2_fb']<300) | (df['actor2_fb']>11000)]
df2= df2[['title', 'actor2_fb']].iloc[0:10, :]

# %%
df2
# Out:
#                                          title  actor2_fb
# 3                        The Dark Knight Rises    23000.0
# 4   Star Wars: Episode VII - The Force Awakens       12.0
# 8                      Avengers: Age of Ultron    21000.0
# 16    The Chronicles of Narnia: Prince Caspian      216.0
# 17                                The Avengers    21000.0
# 26                                     Titanic    14000.0
# 27                  Captain America: Civil War    19000.0
# 33                         Alice in Wonderland    25000.0
# 38                   Oz the Great and Powerful    15000.0
# 45                                   Furious 7    23000.0

# %%
# X = df[df['actor2_fb'] <300]
# Y = df[df['actor2_fb'] >11000]
# df2 = pd.concat([X, Y] ,axis=0)
# df2
# df2[['title', 'actor2_fb']].loc[]

# %% [markdown]
# ### Task 3 : Sort the data complete set by director names

# %%
df3 = df.sort_values(by = 'director_name')
df3.head()
# Out:
#                     title    year  color content_rating  duration  \
# 4498  The Helix... Loaded  2005.0  Color              R      97.0
# 4221               Circle  2015.0  Color      Not Rated      87.0
# 3430              Get Low  2009.0  Color          PG-13     100.0
# 2156           Date Movie  2006.0  Color          PG-13      85.0
# 2862          The Funeral  1996.0  Color              R      99.0
#
#         director_name  director_fb               actor1  actor1_fb  \
# 4498    A. Raven Cruz          0.0           Scott Levy      639.0
# 4221       Aaron Hann          0.0       Jordi Vilasuso      160.0
# 3430  Aaron Schneider         11.0          Bill Murray    13000.0
# 2156    Aaron Seltzer         64.0      Alyson Hannigan     3000.0
# 2862     Abel Ferrara        220.0  Isabella Rossellini      812.0
#
#                   actor2  ...  actor3_fb       gross  \
# 4498         Vanilla Ice  ...       94.0         NaN
# 4221  Michael McLafferty  ...       94.0         NaN
# ...

# %%
df1.to_csv('imbd_score.csv')
df2.to_csv('actor2_fb.csv')
df3.to_csv('sort_director.csv')
